# %% [markdown]
# @author Joubert Alexandrino de Souza
# @version 2020-10-28
#
# -----------------------------------------------
# Ambiente para estudar aprendizado de máquina
# -----------------------------------------------
#
# Escolha um ambiente para estudar aprendizado de máquina.
# Pode ser uma das formas apresentadas no vídeo https://youtu.be/wDkyc8Sv4JM, ou outra forma que você souber.
#
# Faça um jupyter notebook com os códigos apresentados no vídeo https://youtu.be/_dgrpfEuud0.
#
# Disponibilize seu jupyter notebook no GitHub.
#
# Coloque o link do seu notebook no GitHub para entregar a tarefa.

# %% [markdown]
# Aprendizado supervisionado - Regressão

# %%
#Importa as bibliotecas necessárias
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston

#Plota o gráfico
X, y = load_boston(return_X_y=True)
plt.scatter(X[:,12], y)
plt.show()

# %% [markdown]
# Aprendizado supervisionado - Classificação

# %%
#Importa as bibliotecas necessárias
from sklearn.datasets import load_breast_cancer

#Plota o gráfico
X, y = load_breast_cancer(return_X_y=True)
plt.plot(X[:,20][y==1], X[:,27][y==1], "gs")
plt.plot(X[:,20][y==0], X[:,27][y==0], "ro")
plt.show()

# %% [markdown]
# Aprendizado não supervisionado

# %%
#Importa as bibliotecas necessárias
from sklearn.datasets import load_iris

#Plota o gráfico
X, y = load_iris(return_X_y=True)
plt.plot(X[:,0], X[:,1], "o")
plt.show()
